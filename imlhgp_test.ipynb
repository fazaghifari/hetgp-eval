# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.gaussian_process.kernels import RBF, Matern, ConstantKernel, WhiteKernel
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_squared_error

from src.imlhgp import IMLHGP

# %%
def f1(X, add_noise=False):
    target = X * np.sin(X) + np.sqrt(16*X)
    if add_noise:
        rng = np.random.RandomState(1)
        target += rng.normal(0, 1, size=target.shape)
    return target.squeeze()

f2 = np.cos
transform = np.exp

# %% [markdown]
# # Test Data

# %%
X = np.linspace(start=0, stop=10, num=1000).reshape(-1, 1)

# Compute loc and scale as functions of input X
loc = f1(X, add_noise=False).reshape(-1,1)
scale = transform(f2(X))

# Sample outputs Y from Gaussian Likelihood
Y = np.random.normal(loc, scale)

# %% [markdown]
# # Training Data

# %%
rng = np.random.RandomState(0)
X_train = rng.uniform(0, 10, size=25).reshape(-1, 1)
mean_train = f1(X_train, add_noise=False).reshape(-1,1)
scale_train = transform(f2(X_train))

np.random.seed(17)
y_train = np.random.normal(mean_train, scale_train)

# %%
plt.figure(figsize=(15, 5))
x = X.squeeze()
for k in (1, 2):
    lb = (loc - k * scale).squeeze()
    ub = (loc + k * scale).squeeze()
    plt.fill_between(x, lb, ub, color="silver", alpha=1 - 0.05 * k ** 3)
plt.scatter(X_train, y_train)

# %% [markdown]
# # Improved Most Likely Heteroscedastic Gaussian Process approach

# %%
# define the model
kernel = ConstantKernel(1.0) * RBF(length_scale=1e1, length_scale_bounds=(1e-2, 1e3)) + WhiteKernel(
    noise_level=1, noise_level_bounds=(1e-2, 1e1)
)
kernel_noise = ConstantKernel(1.0) * RBF(length_scale=1e1, length_scale_bounds=(1e-2, 1e3)) +  WhiteKernel(
    noise_level=1, noise_level_bounds=(1e-2, 1e2)
)

model = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=25)
model_noise = GaussianProcessRegressor(kernel=kernel_noise, n_restarts_optimizer=25)

hgp = IMLHGP(model, model_noise, v=2)

# fit the model
hgp.fit(X_train, y_train.flatten())

# make a prediction 
Y_pred, Std_pred = hgp.predict(X, return_std="multi")

std_al, std_ep = Std_pred
std_tot = np.sqrt(std_al**2 + std_ep**2)

# %%
sorted_xtrain = np.sort(X_train, axis=0)
plt.scatter(X_train, (hgp.z))
plt.plot(sorted_xtrain, (hgp.model_noise.predict(sorted_xtrain)), "--m")
plt.xlabel("X")
plt.ylabel("z")
# Out:
# Text(0, 0.5, 'z')

# %%
hgp.model_noise.kernel_
# Out:
# 4.29**2 * RBF(length_scale=1.23) + WhiteKernel(noise_level=36.7)

# %%
np.max(std_al)
# Out:
# 2.805370418641816

# %%
std_tot
# Out:
# array([1.85388895, 1.84242727, 1.83117753, 1.82013977, 1.80931397,
#        1.79870006, 1.7882979 , 1.7781073 , 1.76812801, 1.75835971,
#        1.74880202, 1.73945451, 1.73031667, 1.72138795, 1.71266771,
#        1.70415527, 1.69584989, 1.68775074, 1.67985696, 1.6721676 ,
#        1.66468167, 1.65739811, 1.6503158 , 1.64343355, 1.63675013,
#        1.0808112 , 1.06680356, 1.0528031 , 1.0388102 , 1.02482523,
#        1.01084854, 0.99688043, 0.98292117, 0.968971  , 0.95503012,
#        0.94109868, 0.92717679, 0.91326452, 0.89936189, 0.88546884,
#        0.87158529, 0.85771108, 0.84384597, 0.82998968, 0.81614181,
#        0.80230192, 0.78846945, 0.77464375, 0.76082408, 0.74700956,
#        0.7331992 , 0.71939188, 0.70558631, 0.69178106, 0.67797452,
#        0.66416486, 0.65035007, 0.63652787, 0.62269576, 0.6088509 ,
#        0.59499015, 0.58111001, 0.56720657, 0.55327545, 0.53931177,
#        0.52531006, 0.51126415, 0.49716715, 0.48301126, 0.46878765,
#        0.45448631, 0.44009583, 0.42560314, 0.41099318, 0.39624853,
#        0.3813489 , 0.36627043, 0.35098487, 0.33545839, 0.31965006,
#        0.30350964, 0.28697449, 0.26996501, 0.26192067, 0.26072217,
#        0.25955597, 0.25842073, 0.2573151 , 0.25623771, 0.25518716,
#        0.25416207, 0.25316102, 0.25218263, 0.2512255 , 0.25028825,
#        0.24936951, 0.24846796, 0.24758227, 0.24671117, 0.24585342,
#        0.24500783, 0.24417325, 0.24334862, 0.24253291, 0.24172519,
#        0.24092458, 0.2401303 , 0.23934167, 0.23855811, 0.23777912,
#        0.23700434, 0.23623352, 0.23546655, 0.23470346, 0.2339444 ,
#        0.23318971, 0.23243987, 0.23169554, 0.23095756, 0.23022695,
#        0.22950495, 0.228793  , 0.22809275, 0.22740609, 0.22673513,
#        0.22608224, 0.22545004, 0.2248414 , 0.22425949, 0.22370772,
#        0.22318981, 0.22270976, 0.22227185, 0.22188066, 0.22154108,
#        0.22125828, 0.22103771, 0.22088511, 0.22080651, 0.22080819,
#        0.22089666, 0.2210787 , 0.22136126, 0.22175149, 0.2222567 ,
#        0.22288432, 0.22364185, 0.22453687, 0.22557695, 0.22676965,
#        0.22812243, 0.22964265, 0.23133752, 0.23321401, 0.2352789 ,
#        0.23753864, 0.23999939, 0.24266696, 0.24554678, 0.24864388,
#        0.2519629 , 0.25550804, 0.25928306, 0.26329132, 0.26753574,
#        0.27201881, 0.27674264, 0.28170895, 0.28691908, 0.29237403,
#        0.2980745 , 0.30402085, 0.31021322, 0.31665146, 0.32333523,
#        0.330264  , 0.33743703, 0.34485348, 0.35251235, 0.36041254])

# %%
plt.figure(figsize=(15, 5))
plt.scatter(X,Y)
x = X.squeeze()
plt.fill_between(
    X.ravel(),
    Y_pred - 1.96 * (std_al),
    Y_pred + 1.96 * (std_al),
    alpha=0.5,
    label=r"Observed data stdev",
)
plt.fill_between(
    X.ravel(),
    Y_pred - 1.96 * std_tot,
    Y_pred + 1.96 * std_tot,
    alpha=0.5,
    label=r"Prediction uncertainty",
)
plt.plot(X, Y_pred, "--m")
plt.scatter(X_train, y_train)
plt.legend()

# %%
np.exp(hgp.model.kernel_.theta)
# Out:
# array([0.03551824])

# %%
hgp.model.kernel_
# Out:
# 9.22**2 * RBF(length_scale=2.04) + WhiteKernel(noise_level=0.0355)

# %%
X_train.shape
# Out:
# (25, 1)
