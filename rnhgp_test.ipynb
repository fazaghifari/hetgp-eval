# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.gaussian_process.kernels import RBF, Matern, ConstantKernel, WhiteKernel
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_squared_error
import sklearn.preprocessing

from src.rnhgp import RNHGP

# %%
def f1(X, add_noise=False):
    target = X * np.sin(X) + np.sqrt(16*X)
    if add_noise:
        rng = np.random.RandomState(1)
        target += rng.normal(0, 1, size=target.shape)
    return target.squeeze()

f2 = np.cos
transform = np.exp

# %% [markdown]
# # Test Data

# %%
X = np.linspace(start=0, stop=10, num=1000).reshape(-1, 1)

# Compute loc and scale as functions of input X
loc = f1(X, add_noise=False).reshape(-1,1)
scale = transform(f2(X))

# Sample outputs Y from Gaussian Likelihood
Y = np.random.normal(loc, scale)

# %% [markdown]
# # Training Data

# %%
rng = np.random.RandomState(0)
X_train = rng.uniform(0, 10, size=20).reshape(-1, 1)
mean_train = f1(X_train, add_noise=False).reshape(-1,1)
scale_train = transform(f2(X_train))

np.random.seed(17)
y_train = np.random.normal(mean_train, scale_train)

# %%
plt.figure(figsize=(15, 5))
x = X.squeeze()
for k in (1, 2):
    lb = (loc - k * scale).squeeze()
    ub = (loc + k * scale).squeeze()
    plt.fill_between(x, lb, ub, color="silver", alpha=1 - 0.05 * k ** 3)
plt.scatter(X_train, y_train)

# %% [markdown]
# # Radius Neighbor Most Likely Heteroscedastic Gaussian Process approach

# %%
# Normalize X
normalizer = sklearn.preprocessing.StandardScaler().fit(X_train)
X_train_norm = normalizer.transform(X_train)
X_norm = normalizer.transform(X)

# define the model
kernel = ConstantKernel(1.0) * RBF(length_scale=1e1, length_scale_bounds=(1e-2, 1)) + WhiteKernel(
    noise_level=1, noise_level_bounds=(1e-3, 1e1)
)
kernel_noise = ConstantKernel(1.0) * RBF(length_scale=1e1, length_scale_bounds=(1e-2, 1e3)) +  WhiteKernel(
    noise_level=1, noise_level_bounds=(1e-2, 1e2)
)

model = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=25)
model_noise = GaussianProcessRegressor(kernel=kernel_noise, n_restarts_optimizer=25)

hgp = RNHGP(model, model_noise, max_iter=10)

# fit the model
hgp.fit(X_train, y_train.flatten())

# make a prediction 
Y_pred, Std_pred = hgp.predict(X, return_std="multi")

std_al, std_ep = Std_pred
std_tot = np.sqrt(std_al**2 + std_ep**2)
# Out:
# /Users/fazaghifari/miniconda3/envs/raenv/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 6.35**2 * RBF(length_scale=12.5)
# 8.24**2 * RBF(length_scale=7.21)
# 9.14**2 * RBF(length_scale=6.27)
# 8.61**2 * RBF(length_scale=5.05)
# 8.48**2 * RBF(length_scale=2.04)
# 9.16**2 * RBF(length_scale=1.98)
# 9.34**2 * RBF(length_scale=2)
# 9.34**2 * RBF(length_scale=2.01)
# 9.34**2 * RBF(length_scale=2.01)

# %%
sorted_xtrain = np.sort(X_train, axis=0)
sorted_xtrain_norm = np.sort(X_train_norm, axis=0)
plt.scatter(X_train, (hgp.z), marker="^", color="green")
plt.plot(sorted_xtrain, (hgp.model_smoothing.predict(sorted_xtrain)), "-.k")
plt.plot(sorted_xtrain, (hgp.model_noise.predict(sorted_xtrain)), "--m")
plt.xlabel("X")
plt.ylabel("z")
# Out:
# Text(0, 0.5, 'z')

# %%
hgp.model_noise.kernel_
# Out:
# 4.6**2 * RBF(length_scale=1.18) + WhiteKernel(noise_level=0.491)

# %%
hgp.model.kernel_
# Out:
# 9.34**2 * RBF(length_scale=2.01)

# %%
np.max(std_al)
# Out:
# 3.4322049081176456

# %%
np.max(std_al)
# Out:
# 3.4322049081176456

# %%
plt.figure(figsize=(15, 5))
plt.scatter(X,Y)
x = X.squeeze()
plt.fill_between(
    X.ravel(),
    Y_pred - 1.96 * (std_al),
    Y_pred + 1.96 * (std_al),
    alpha=0.5,
    label=r"Observed data stdev",
)
plt.fill_between(
    X.ravel(),
    Y_pred - 1.96 * std_tot,
    Y_pred + 1.96 * std_tot,
    alpha=0.5,
    label=r"Prediction uncertainty",
)
plt.plot(X, Y_pred, "--m")
plt.scatter(X_train, y_train)
plt.legend()

# %%
np.exp(hgp.model.kernel_.theta)
# Out:
# array([87.26301181,  2.00924699])

# %%
hgp.model.kernel_
# Out:
# 9.34**2 * RBF(length_scale=2.01)

# %%
X_train.shape
# Out:
# (20, 1)
